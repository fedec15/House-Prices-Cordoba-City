# %%
import pandas as pd

# %%
df1 = pd.read_excel('Barrios.xlsx')
df2 = pd.read_excel('Tipo_de_Barrio.xlsx')
df2
# Out:
#                Con Seguridad                    Cerrado  \
# 0               Greenville 2              Ayres del Sur
# 1                Manantiales           Palmas de Claret
# 2       Altos de Manantiales              Santina Norte
# 3   Miradores de Manantiales                  Terranova
# 4     Riberas de Manantiales            Valle Escondido
# 5     Solares de Santa María              Valle Cercano
# 6           Chacra del Norte            Tejas del Sur I
# 7         Comarca de Allende           Tejas del Sur II
# 8                   El Rodeo                 La Reserva
# 9                Los Mimbres                Siete Soles
# 10                 La Paya I         Estancia La Lucila
# 11                La Paya II          Claros del Bosque
# 12              Barranquitas            Cuesta Colorada
# 13           Barrancas Norte             Paso de Piedra
# 14            Chacra del Sur             Valle del Golf
# 15         Lomas del Chateau                Las Cañitas
# ...

# %%
df.to_csv('Barrios.csv', encoding='utf_8_sig')
df.to_csv('Tipo_de_Barrio.csv', encoding='utf_8_sig')
