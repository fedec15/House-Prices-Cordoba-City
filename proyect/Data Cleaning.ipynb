# %% [markdown]
# # ***Data Cleaning of Casas_venta***

# %% [markdown]
# ## **Importing Libraries & loading Data**

# %%
# Import libraries
import numpy as np
from scipy.stats import norm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from operator import itemgetter

from scipy import stats
from scipy.stats import norm, skew #for some statistics

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points

# %%
# Loading 'Casas_venta_LaVoz.csv', 'Casas_venta_zonaprop.csv', and 'Casas_venta_argenprop.csv' 
df1 = pd.read_csv('data/Casas_venta_LaVoz.csv')
df1.columns = df1.columns.str.replace('Apto Crédito:','Apto Crédito')
df1.drop(columns=['Unnamed: 0'], inplace=True)
print('Lenght:',len(df1))

df2 = pd.read_csv('data/Casas_venta_zonaprop.csv')
df2.drop(columns=['Unnamed: 0'], inplace=True)
print('Lenght:',len(df2))

df3 = pd.read_csv('data/Casas_venta_argenprop.csv')
df3.drop(columns=['Unnamed: 0'], inplace=True)
print('Lenght:',len(df3))
# Out:
# Lenght: 13491
# Lenght: 7198
# Lenght: 2797

# %%
df = pd.concat([df1,df2,df3])
df = df.reset_index()
df.drop(columns=['index'], inplace=True)
for i in df.columns:
  df[i] = df[i].astype(str)
  df[i] = df[i].replace('nan',np.NaN)
print('Lenght:',len(df))
df.head()
# Out:
# Lenght: 23486
#   Tipo de Propiedad   Zona         Ciudad             Barrio  \
# 0            Duplex    NaN        Córdoba  Claros del Bosque
# 1            Duplex    Sur        Córdoba       Greenville 2
# 2              Casa    NaN  Villa Allende       La Herradura
# 3              Casa  Norte        Córdoba     Villa Belgrano
# 4              Casa    NaN        Córdoba    Maipu Sección 2
#
#                      Calle Tipo de Barrio Apto Escritura  Apto Crédito  \
# 0   Claros Del Bosque 5000            NaN            NaN           nan
# 1                      NaN  Con Seguridad            NaN           nan
# 2                     01 1        Country            NaN           nan
# 3                      NaN        Abierto             Si           nan
# 4  Benjamin Igarzabal 1300            NaN            NaN           nan
#
#   Etapa de Construcción Antigüedad Cantidad de Plantas  \
# 0                   NaN        NaN           2 Plantas
# 1                   NaN        NaN                 NaN
# 2                   NaN        NaN           2 Plantas
# 3                   NaN    25 años            1 Planta
# 4                   NaN        NaN                 NaN
#
#   Cantidad de Dormitorios Cantidad de Baños Cantidad de Cocheras  \
# 0           3 Dormitorios           3 Baños                    1
# 1           3 Dormitorios               NaN                  NaN
# 2           3 Dormitorios           3 Baños                    2
# 3           3 Dormitorios           4 Baños                    2
# 4           4 Dormitorios           4 Baños                    2
#
#   Cobertura Cocheras Superficie Total m2 Superficie Cubierta m2   Valor
# 0           Cubierta                 180                    160  185000
# 1                NaN                 NaN                    NaN  225000
# 2           Cubierta                1592                    400  380000
# 3           Cubierta          1.200 mts2               446 mts2  420000
# 4           Cubierta                 350                    316  250000

# %%
# selecting houses only from Córdoba city and its surrounding ('Gran Córdoba')
col = ['Córdoba', 'Villa Allende', 
       'Mendiolaza','La Calera', 
       'Valle Escondido','Guiñazú',
       'Malagueño', 'Pdo. de Cordoba Capital'
       'Countries y Barrios Cerrados Cordoba Capital']

df = df.loc[(df.Ciudad == col[0]) | 
            (df.Ciudad == col[1]) | 
            (df.Ciudad == col[2]) | 
            (df.Ciudad == col[3]) | 
            (df.Ciudad == col[4]) | 
            (df.Ciudad == col[5]) |
            (df.Ciudad == col[6]) |
            (df.Ciudad == col[7]) 
           ] 
len(df) # lenght: 15938 rows
# Out:
# 15938

# %% [markdown]
# ## **Main feature/dependent variable/ ('Valor)'**

# %%
# Dropping rows with NaN values in 'Valor'
df.dropna(subset=['Valor'], inplace=True) 
len(df) #lenght: 7375 rows
# Out:
# 13158

# %%
# Converting 'Valor' values into float
df.Valor = df.Valor.str.extract('(\d+)').astype(float)

# %%
# dropping values < U$S 5.000.000 and > 10000 to avoid possible error-numbers from collected data
df = df.loc[(df.Valor < 5000000) & (df.Valor > 5000)]

# %%
# First approximation to 'Valor', looking for outliers and shape of distribution
plt.subplot(1, 2, 1)
plt.hist(df.Valor)
plt.subplot(1, 2, 2)
sns.boxplot(df.Valor)
plt.show()

# %%
# Cleaning big outliers
df = df.loc[(df.Valor < 1000000)]
plt.subplot(1, 2, 1)
plt.hist(df.Valor)
plt.subplot(1, 2, 2)
sns.boxplot(df.Valor)
print('Lenght:',len(df))
plt.show()
# Out:
# Lenght: 12548

# %% [markdown]
# ## **Categorical Features**

# %%
# Looking for # of NaN in each feature
t = {}
for i in df.columns:
  t[i] = (df[i].isnull().sum())
sorted(t.items(), key=itemgetter(1))
# Out:
# [('Ciudad', 0),
#  ('Valor', 0),
#  ('Tipo de Propiedad', 299),
#  ('Cantidad de Dormitorios', 787),
#  ('Barrio', 1798),
#  ('Calle', 2719),
#  ('Superficie Total m2', 3220),
#  ('Superficie Cubierta m2', 3400),
#  ('Cantidad de Baños', 3764),
#  ('Cantidad de Cocheras', 6147),
#  ('Antigüedad', 6472),
#  ('Cantidad de Plantas', 7488),
#  ('Tipo de Barrio', 8070),
#  ('Apto Escritura', 9029),
#  ('Cobertura Cocheras', 9376),
#  ('Zona', 9715),
#  ('Etapa de Construcción', 9992),
#  ('Apto Crédito', 12548)]

# %%
# Removing columns with either hight number of NaN or no relevance
columns = ['Tipo de Propiedad',
           'Zona', # although it has a big number of NaN, I will impute them with data from other source
           'Barrio',
           'Calle',
           'Tipo de Barrio', # although it has a big number of NaN, I will impute them with data from other source
           'Cantidad de Dormitorios',
           'Cantidad de Baños', # although it has a big number of NaN, I will impute them with its mode
           'Cantidad de Cocheras',
           'Cobertura Cocheras',
           'Superficie Cubierta m2',
           'Superficie Total m2',
           'Valor'
          ]

df = df[columns]
df.head()
# Out:
#   Tipo de Propiedad   Zona             Barrio                    Calle  \
# 0            Duplex    NaN  Claros del Bosque   Claros Del Bosque 5000
# 1            Duplex    Sur       Greenville 2                      NaN
# 2              Casa    NaN       La Herradura                     01 1
# 3              Casa  Norte     Villa Belgrano                      NaN
# 4              Casa    NaN    Maipu Sección 2  Benjamin Igarzabal 1300
#
#   Tipo de Barrio Cantidad de Dormitorios Cantidad de Baños  \
# 0            NaN           3 Dormitorios           3 Baños
# 1  Con Seguridad           3 Dormitorios               NaN
# 2        Country           3 Dormitorios           3 Baños
# 3        Abierto           3 Dormitorios           4 Baños
# 4            NaN           4 Dormitorios           4 Baños
#
#   Cantidad de Cocheras Cobertura Cocheras Superficie Cubierta m2  \
# 0                    1           Cubierta                    160
# 1                  NaN                NaN                    NaN
# 2                    2           Cubierta                    400
# 3                    2           Cubierta               446 mts2
# 4                    2           Cubierta                    316
#
#   Superficie Total m2      Valor
# 0                 180 185000.000
# 1                 NaN 225000.000
# 2                1592 380000.000
# 3          1.200 mts2 420000.000
# 4                 350 250000.000

# %% [markdown]
# ### **Cleaning 'Tipo de Propiedad'**

# %%
# Droping the few rows with an empty element in the column 'Tipo de Propiedad'
df.dropna(subset=['Tipo de Propiedad'], inplace=True)
print('Tipo de Propiedad:', df['Tipo de Propiedad'].unique())
# Out:
# Tipo de Propiedad: ['Duplex' 'Casa' 'Chalet' 'Casa Quinta' 'Triplex' 'Prefabricada' 'Cabaña'
#  'Departamento']

# %%
for i in df['Tipo de Propiedad'].unique():
  print(i+':', len(df.loc[df['Tipo de Propiedad'] == i]) )
# Out:
# Duplex: 825
# Casa: 11390
# Chalet: 10
# Casa Quinta: 6
# Triplex: 11
# Prefabricada: 1
# Cabaña: 1
# Departamento: 5

# %%
# Removing values 'Chalet', 'Triplex', 'Casa Quinta' & 'Cabaña' as their sum is 12 
df = df.loc[(df['Tipo de Propiedad'] == 'Duplex') | (df['Tipo de Propiedad'] == 'Casa') ]
print('Tipo de Propiedad:', df['Tipo de Propiedad'].unique())
print('Lenght:', len(df))
# Out:
# Tipo de Propiedad: ['Duplex' 'Casa']
# Lenght: 12215

# %% [markdown]
# ### **Cleaning 'Cantidad de Cocheras' & 'Cobertura Cocheras'**

# %%
# Replacing NaN from 'Cantidad de Cocheras' with value '1' when 'Cobertura Cocheras' is not null
df['Cantidad de Cocheras'] = np.where((df['Cantidad de Cocheras'].isnull()) & (df['Cobertura Cocheras'].notnull()), '1', df['Cantidad de Cocheras'])
df['Cantidad de Cocheras'] = df['Cantidad de Cocheras'].astype(float)
df['Cantidad de Cocheras'] = np.where(df['Cantidad de Cocheras'] > 4, 5, df['Cantidad de Cocheras'])
df.drop(columns=['Cobertura Cocheras'], inplace=True)
df['Cantidad de Cocheras'].unique()
# Out:
# array([ 1., nan,  2.,  3.,  4.,  5.,  0.])

# %%
# Creating a new column with data about the NaN status of each row (true/false)
df['Cantidad de Cocheras' + '_was_missing'] = df['Cantidad de Cocheras'].isnull()

# %%
# Imputing NaN values with value '0'
df['Cantidad de Cocheras'].fillna(0, inplace=True)
print('Total NaN Cantidad de Cocheras:', df['Cantidad de Cocheras'].isnull().sum())
print('Lenght:',len(df))
df.head()
# Out:
# Total NaN Cantidad de Cocheras: 0
# Lenght: 12215
#   Tipo de Propiedad   Zona             Barrio                    Calle  \
# 0            Duplex    NaN  Claros del Bosque   Claros Del Bosque 5000
# 1            Duplex    Sur       Greenville 2                      NaN
# 2              Casa    NaN       La Herradura                     01 1
# 3              Casa  Norte     Villa Belgrano                      NaN
# 4              Casa    NaN    Maipu Sección 2  Benjamin Igarzabal 1300
#
#   Tipo de Barrio Cantidad de Dormitorios Cantidad de Baños  \
# 0            NaN           3 Dormitorios           3 Baños
# 1  Con Seguridad           3 Dormitorios               NaN
# 2        Country           3 Dormitorios           3 Baños
# 3        Abierto           3 Dormitorios           4 Baños
# 4            NaN           4 Dormitorios           4 Baños
#
#    Cantidad de Cocheras Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                 1.000                    160                 180 185000.000
# 1                 0.000                    NaN                 NaN 225000.000
# 2                 2.000                    400                1592 380000.000
# 3                 2.000               446 mts2          1.200 mts2 420000.000
# 4                 2.000                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing
# 0                             False
# 1                              True
# 2                             False
# 3                             False
# 4                             False

# %% [markdown]
# ### **Cleaning 'Cantidad de Dormitorios' & 'Cantidad de Baños'**

# %%
# Getting kind of values from 'Cantidad de Dormitorios' & 'Cantidad de Baños' 
print('Cantidad de Dormitorios:', df['Cantidad de Dormitorios'].unique())
print('Cantidad de Baños:', df['Cantidad de Baños'].unique())
# Out:
# Cantidad de Dormitorios: ['3 Dormitorios' '4 Dormitorios' '2 Dormitorios' 'Más de 4 Dormitorios'
#  nan '1 Dormitorio' 'Monoambiente' '3.0' '2.0' '4.0' '5.0' '0.0' '7.0'
#  '6.0' '14.0' '8.0' '10.0' '1.0']
# Cantidad de Baños: ['3 Baños' nan '4 Baños' '2 Baños' '1 Baño' 'Más de 4 Baños' '3.0' '4.0'
#  '2.0' '0.0' '5.0' '6.0' '7.0' '10.0' '8.0' '1.0']

# %%
# Replacing their values with numerical data  
l = df['Cantidad de Dormitorios'].loc[df['Cantidad de Dormitorios'] == 'Monoambiente']
df['Cantidad de Dormitorios'].replace(l, '5', inplace=True)
l = df['Cantidad de Dormitorios'].loc[df['Cantidad de Dormitorios'] == 'Más de 4 Dormitorios']
df['Cantidad de Dormitorios'].replace(l, '5', inplace=True)
l = df['Cantidad de Baños'].loc[df['Cantidad de Baños'] == 'Más de 4 Baños']
df['Cantidad de Baños'].replace(l, '5', inplace=True)
df['Cantidad de Dormitorios'] = df['Cantidad de Dormitorios'].astype(str).str.extract('(\d+)').astype(float)
df['Cantidad de Baños'] = df['Cantidad de Baños'].astype(str).str.extract('(\d+)').astype(float)

# %%
df['Cantidad de Dormitorios'] = np.where(df['Cantidad de Dormitorios'] > 4, 5, df['Cantidad de Dormitorios'])
df['Cantidad de Dormitorios'] = np.where(df['Cantidad de Dormitorios'] == 0, np.NaN, df['Cantidad de Dormitorios'])
df['Cantidad de Baños'] = np.where(df['Cantidad de Baños'] > 4, 5, df['Cantidad de Baños'])
df['Cantidad de Baños'] = np.where(df['Cantidad de Baños'] == 0, np.NaN, df['Cantidad de Baños'])
print('Cantidad de Dormitorios:', df['Cantidad de Dormitorios'].unique())
print('Cantidad de Baños:', df['Cantidad de Baños'].unique())
# Out:
# Cantidad de Dormitorios: [ 3.  4.  2.  5. nan  1.]
# Cantidad de Baños: [ 3. nan  4.  2.  1.  5.]

# %%
# Creating new columns with data about the replacement of NaN
for i in ['Cantidad de Dormitorios','Cantidad de Baños']:
  df[i + '_was_missing'] = df[i].isnull()

# %%
# Imputing NaN values with their modes
df['Cantidad de Dormitorios'].fillna(df['Cantidad de Baños'].mode()[0], inplace=True)
df['Cantidad de Baños'].fillna(df['Cantidad de Baños'].mode()[0], inplace=True)
print('Total NaN Cantidad de Dormitorios:', df['Cantidad de Dormitorios'].isnull().sum())
print('Total NaN Cantidad de Baños:',df['Cantidad de Baños'].isnull().sum())
print('Lenght:',len(df))
df.head()
# Out:
# Total NaN Cantidad de Dormitorios: 0
# Total NaN Cantidad de Baños: 0
# Lenght: 12215
#   Tipo de Propiedad   Zona             Barrio                    Calle  \
# 0            Duplex    NaN  Claros del Bosque   Claros Del Bosque 5000
# 1            Duplex    Sur       Greenville 2                      NaN
# 2              Casa    NaN       La Herradura                     01 1
# 3              Casa  Norte     Villa Belgrano                      NaN
# 4              Casa    NaN    Maipu Sección 2  Benjamin Igarzabal 1300
#
#   Tipo de Barrio  Cantidad de Dormitorios  Cantidad de Baños  \
# 0            NaN                    3.000              3.000
# 1  Con Seguridad                    3.000              2.000
# 2        Country                    3.000              3.000
# 3        Abierto                    3.000              4.000
# 4            NaN                    4.000              4.000
#
#    Cantidad de Cocheras Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                 1.000                    160                 180 185000.000
# 1                 0.000                    NaN                 NaN 225000.000
# 2                 2.000                    400                1592 380000.000
# 3                 2.000               446 mts2          1.200 mts2 420000.000
# 4                 2.000                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing  Cantidad de Dormitorios_was_missing  \
# 0                             False                                False
# 1                              True                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Cantidad de Baños_was_missing
# 0                          False
# 1                           True
# 2                          False
# 3                          False
# 4                          False

# %% [markdown]
# ### **Cleaning 'Barrio'**

# %%
# Replacing value 'Córdoba' in 'Barrio' with values from 'Calle'
df.Barrio = np.where(df.Barrio == 'Córdoba', df.Calle, df.Barrio)

# Dropping column 'Calle'
df.drop(columns=['Calle'], inplace=True)

# Converting data from 'Barrio' as string
df['Barrio'] = df['Barrio'].astype(str)

# Removing specific chars in 'Barrio'
df.Barrio = [i.replace('.','') for i in df.Barrio] 
df.Barrio = [i.replace('Los Carolinos','Lomas de la Carolina') for i in df.Barrio] 
df.Barrio = [i.replace('Urbanización Inteligente','') for i in df.Barrio]
df.Barrio = [i.replace('Barrio Privado','') for i in df.Barrio]
df.Barrio = [i.replace('Urbanizacion Residencial','') for i in df.Barrio] 
df.Barrio = [i.replace('Villa Urbana','') for i in df.Barrio] 
df.Barrio = [i.replace('Urbanización','') for i in df.Barrio] 
df.Barrio = [i.replace('El Jockey','Jockey Club') for i in df.Barrio] 
df.Barrio = [i.replace('El Talar','El Talar de Mendiolaza') for i in df.Barrio] 
df.Barrio = [i.replace('4','Cuatro') for i in df.Barrio] 
df.Barrio.loc[df.Barrio != 'Solares de San Alfonso'] = [i.replace('San Alfonso','San Alfonso del Talar') for i in df.Barrio if i != 'Solares de San Alfonso' ] 
df.Barrio.loc[df.Barrio != 'Country Club'] = [i.replace('Country','') for i in df.Barrio if i != 'Country Club' ]
df.Barrio.loc[(df.Barrio != 'Centro')&(df.Barrio != 'Centro América')] = [i.replace('Centro','') for i in df.Barrio if (i != 'Centro' and i != 'Centro América')]

# %%
# Loading 'Barrios.csv', which contains the name and 'Zona' for each 'Barrio'
barrios = pd.read_csv('/data/barrios/Barrios.csv')
barrios.drop(columns=['Unnamed: 0'], inplace=True)
barrios.head()
# Out:
#         Zona Central                Zona Norte     Zona Sur  \
# 0            Cáceres    Parque Liceo Sección 1      Mirizzi
# 1             Güemes                    Cofico        Irupé
# 2      Nueva Córdoba  Jerónimo Luis de Cabrera  San Antonio
# 3       Observatorio   Ampliación Panamericano  Cabo Farina
# 4  Paso de los Andes              Panamericano        Vicor
#
#             Zona Este               Zona Oeste           Zona Nordeste  \
# 0  General Pueyrredón    Ampliación Las Palmas            La Hortensia
# 1           Yofre Sud         Chateau Carreras      Residencial Aragón
# 2        Hogar Propio            Puente Blanco            Vivero Norte
# 3             Juniors  Ampliación Los Plátanos            Villa Retiro
# 4   Ampliación Yapeyú             Villa Siburu  Parque Liceo Sección 3
#
#             Zona Noroeste                 Zona Sudeste  \
# 0        San Martín Anexo  José Ignacio Díaz Sección 5
# 1        San Martín Norte                      Mirador
# 2          Las Margaritas         Ampliación San Pablo
# 3     Lomas de San Martín                  Villa Revol
# 4  Altos de Villa Cabrera            Ferroviario Mitre
#
#               Zona Sudoeste Zona Cerro-Argüello          Zona Guiñazú
# 0  Guarnición Aérea Córdoba       Villa Serrana           Guiñazú Sud
# 1        Ampliación Rosedal       Parque Modelo               Guiñazú
# 2          Parque Republica               UOCRA  Remedios de Escalada
# 3              Achával Peña     Granja de Funes      Recreo del Norte
# 4        Residencial Olivos    Villa 9 de Julio     Liceo General Paz

# %%
# Cleaning 'Barrio's values by comparing them with the fixed dataset of barrios's name in 'Barrios.csv'
import unicodedata
def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")
    return str(text)
  
from difflib import SequenceMatcher
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

barr = []

for i in df.Barrio:
  similar_ratio = []
  if i == 'nan':
    barr.append('nan')
  elif i == 'Otro':
    barr.append('nan')
  else:
    for j in barrios.astype(str).values:
      valor_ratio = []
      for x in j:
        valor_ratio.append([similar(strip_accents(i.lower()), strip_accents(x.lower())), x])
      similar_ratio.append(valor_ratio)
    comparable = []
    for ratio in similar_ratio:
      comparable.append(max(ratio)) 
    if max(comparable)[0]>=0.7:
      barr.append(max(comparable)[1])
    else:
      barr.append('nan')

s = pd.DataFrame(barr, columns=['Barrio2'])
df = df.reset_index(drop=True)
df.Barrio = s.Barrio2
df.head()
# Out:
# Claros del Bosque | Claros del Bosque | 1.0
# Greenville 2 | Greenville 2 | 1.0
# La Herradura | La Herradura | 1.0
# Villa Belgrano | Villa Belgrano | 1.0
# Maipu Sección 2 | Maipú Sección 2 | 1.0
# San Isidro | San Isidro | 1.0
# Maipu Sección 2 | Maipú Sección 2 | 1.0
# Manantiales | Manantiales | 1.0
# Arguello | Argüello | 1.0
# General Paz | General Paz | 1.0
# Urca | Urca | 1.0
# Urca | Urca | 1.0
# Zumaran | Zumaran | 1.0
# Parque Horizonte | Parque Horizonte | 1.0
# Urca | Urca | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Solares de Santa María | Solares de Santa María | 1.0
# Matienzo | Matienzo | 1.0
# La Cuesta | La Cuesta | 1.0
# Chacra del Norte | Chacra del Norte | 1.0
# La Rufina | La Rufina | 1.0
# Villa Warcalde | Villa Warcalde | 1.0
# Alta Córdoba | Alta Córdoba | 1.0
# Comarca de Allende | Comarca de Allende | 1.0
# Chacra del Norte | Chacra del Norte | 1.0
# El Rodeo | El Rodeo | 1.0
# Golf | Golf | 1.0
# Nueva Córdoba | Nueva Córdoba | 1.0
# Alto Alberdi | Alto Alberdi | 1.0
# Nueva Córdoba | Nueva Córdoba | 1.0
# Manantiales | Manantiales | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Palmas de Claret | Palmas de Claret | 1.0
# Villa Warcalde | Villa Warcalde | 1.0
# Valle Escondido | Valle Escondido | 1.0
# Valle Escondido | Valle Escondido | 1.0
# Cofico | Cofico | 1.0
# General Paz | General Paz | 1.0
# Urca | Urca | 1.0
# Alto Verde | Alto Verde | 1.0
# Villa Cabrera | Villa Cabrera | 1.0
# Villa Belgrano | Villa Belgrano | 1.0
# Villa Belgrano | Villa Belgrano | 1.0
# Cañuelas | Cañuelas | 1.0
# Condor Alto | Condor Alto | 1.0
# Cofico | Cofico | 1.0
# La Cuesta | La Cuesta | 1.0
# Lomas de la Carolina | Lomas de la Carolina | 1.0
# Alt de San Martín | Altos de San Martín | 0.9444444444444444
# Jardín Espinosa | Jardín Espinosa | 1.0
# Escobar | Escobar | 1.0
# Pque Montecristo | Parque Montecristo | 0.9411764705882353
# Miradores de Manantiales | Miradores de Manantiales | 1.0
# Palermo Bajo | Palermo Bajo | 1.0
# Las Delicias | Las Delicias | 1.0
# Jardín Espinosa | Jardín Espinosa | 1.0
# Quebrada de las Rosas | Quebrada de las Rosas | 1.0
# Chacras de la Villa | Chacras de la Villa | 1.0
# Ayacucho | Ayacucho | 1.0
# Escobar | Escobar | 1.0
# Valle Escondido | Valle Escondido | 1.0
# Horizonte | Parque Horizonte | 0.72
# Jardín | Jardín | 1.0
# Cuatro Hojas | Cuatro Hojas | 1.0
# Arguello | Argüello | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# General Paz | General Paz | 1.0
# Cuesta Colorada | Cuesta Colorada | 1.0
# Lomas Este | Lomas Este | 1.0
# Tejas 3 | Tejas III | 0.75
# Tejas 3 | Tejas III | 0.75
# Villa Warcalde | Villa Warcalde | 1.0
#  de Villa Allende | Villa Allende | 0.8666666666666667
# LOS MIMBRES  | Los Mimbres | 0.9565217391304348
# Miradores de Manantiales | Miradores de Manantiales | 1.0
# Colinas de V Sarsfield | Colinas de Vélez Sársfield | 0.9166666666666666
# Valle Escondido | Valle Escondido | 1.0
# Tejas del Sur I | Tejas del Sur I | 1.0
# La Paya II | La Paya II | 1.0
# General Paz | General Paz | 1.0
# San Alfonso del Talar | San Alfonso del Talar | 1.0
# Pque Velez Sarsfield | Parque Vélez Sársfield | 0.9523809523809523
# Comarca de Allende | Comarca de Allende | 1.0
# Urca | Urca | 1.0
# Villa Belgrano | Villa Belgrano | 1.0
#
 1.0
# Cerro de las Rosas | Cerro de las Rosas | 1.0
# Chacra del Norte | Chacra del Norte | 1.0
# San Martin | San Martín | 1.0
# Fincas del Sur II | Fincas Del Sur II | 1.0
# Comarca de Allende | Comarca de Allende | 1.0
# Quebrada de las Rosas | Quebrada de las Rosas | 1.0
# San Salvador | San Salvador | 1.0
# Villa Marta | Villa Marta | 1.0
# Alejandro Centeno | Alejandro Centeno | 1.0
# Parque Horizonte | Parque Horizonte | 1.0
# Cinco Lomas | Cinco Lomas | 1.0
# Valle Escondido | Valle Escondido | 1.0
# Paso de los Andes | Paso de los Andes | 1.0
# General Paz | General Paz | 1.0
# Los Naranjos | Los Naranjos | 1.0
# Chacra del Norte | Chacra del Norte | 1.0
# Alberdi | Alberdi | 1.0
# Jardín Espinosa | Jardín Espinosa | 1.0
# Valle Escondido | Valle Escondido | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Solares de Santa María | Solares de Santa María | 1.0
# Cerro de las Rosas | Cerro de las Rosas | 1.0
# Cerro de las Rosas | Cerro de las Rosas | 1.0
# Chacra del Norte | Chacra del Norte | 1.0
# Pque Velez Sarsfield | Parque Vélez Sársfield | 0.9523809523809523
# La Cuesta | La Cuesta | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Res Velez Sarfield | Res. Vélez Sársfield | 0.9473684210526315
# Lomas de la Carolina | Lomas de la Carolina | 1.0
# Siete Soles | Siete Soles | 1.0
# Marq de Sobremonte | Marqués de Sobremonte | 0.9230769230769231
# Valle Escondido | Valle Escondido | 1.0
# La Paya I | La Paya I | 1.0
# Nuevo Poeta Lugones | Poeta Lugones | 0.8125
# Cañuelas | Cañuelas | 1.0
# Manantiales | Manantiales | 1.0
# Siete Soles | Siete Soles | 1.0
# Estancia Q2 | Estancia Q2 | 1.0
# Siete Soles | Siete Soles | 1.0
# Alto Alberdi | Alto Alberdi | 1.0
# Chacras de la Villa | Chacras de la Villa | 1.0
# Arguello | Argüello | 1.0
# Manantiales | Manantiales | 1.0
# Los Naranjos | Los Naranjos | 1.0
# Miradores de Manantiales | Miradores de Manantiales | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# El Bosque | El Bosque | 1.0
# Riberas de Manantiales | Riberas de Manantiales | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Jardín | Jardín | 1.0
# San Fernando | San Fernando | 1.0
# Villa Cabrera | Villa Cabrera | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Cerro de las Rosas | Cerro de las Rosas | 1.0
# Miradores de Manantiales | Miradores de Manantiales | 1.0
# Estancia Q2 | Estancia Q2 | 1.0
# Riberas de Manantiales | Riberas de Manantiales | 1.0
# El Bosque | El Bosque | 1.0
# Chacras de la Villa | Chacras de la Villa | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Arguello | Argüello | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# Jardín | Jardín | 1.0
# Alto Alberdi | Alto Alberdi | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Docta  | Docta | 0.9090909090909091
# Jardín | Jardín | 1.0
# Chacra del Sur | Chacra del Sur | 1.0
# San Fernando | San Fernando | 1.0
# Villa Cabrera | Villa Cabrera | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Claros del Bosque | Claros del Bosque | 1.0
# Cerro de las Rosas | Cerro de las Rosas | 1.0
# 4              Casa    NaN    Maipú Sección 2            NaN
#
#    Cantidad de Dormitorios  Cantidad de Baños  Cantidad de Cocheras  \
# 0                    3.000              3.000                 1.000
# 1                    3.000              2.000                 0.000
# 2                    3.000              3.000                 2.000
# 3                    3.000              4.000                 2.000
# 4                    4.000              4.000                 2.000
#
#   Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                    160                 180 185000.000
# 1                    NaN                 NaN 225000.000
# 2                    400                1592 380000.000
# 3               446 mts2          1.200 mts2 420000.000
# 4                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing  Cantidad de Dormitorios_was_missing  \
# 0                             False                                False
# 1                              True                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Cantidad de Baños_was_missing
# 0                          False
# 1                           True
# 2                          False
# 3                          False
# 4                          False

# %%
# Creating a new column containing references about the replaced NaN values in 'Barrio'
df.Barrio = df.Barrio.replace('nan',np.NaN)
print('Lenght of Barrio\'s NaN:', len(df.loc[df.Barrio.isnull()]))
print('Lenght of Barrios NaN & Zonas NaN:', len(df.loc[ (df.Zona.isnull()) & (df.Barrio.isnull())]) ) 
df['Barrio_was_missing'] = df.Barrio.isnull()

# Removing rows with NaN in both 'Zona' and 'Barrio'
print('Lenght of dataframe befores removing:', len(df))
df = df.loc[ (df.Zona.notnull()) | (df.Barrio.notnull()) ] 
print('Lenght of dataframe after removing:', len(df))

# Imputing NaN values from 'Barrio' with the value 'Otro'
df.Barrio.fillna('Otro',inplace=True)
print('Lenght of Barrio\'s NaN:', len(df.loc[df.Barrio.isnull()]))
print('Lenght of dataframe:', len(df))
# Out:
# Lenght of Barrio's NaN: 2995
# Lenght of Barrios NaN & Zonas NaN: 2711
# Lenght of dataframe befores removing: 12215
# Lenght of dataframe after removing: 9504
# Lenght of Barrio's NaN: 0
# Lenght of dataframe: 9504

# %% [markdown]
# ### **Cleaning 'Zona' **

# %%
# Converting data from 'Zona' as string
df['Zona'] = df['Zona'].astype(str)

# %%
# Inserting a new column 'Zonas' with zone-values got from comparing 'Barrios' with the data in 'Barrios.csv'
zonas = []
for i in df.Barrio:
  boolean = True
  if i == 'Otro':
    zonas.append(np.NaN)
  else:    
    for j in barrios.astype(str).values:
      for x in j:
        if i == x:
          zonas.append(barrios.columns[barrios.isin([x]).any()][0])
          boolean = False
        if not boolean:
          break

s = pd.DataFrame(zonas, columns=['Zonas'])
df = df.reset_index(drop=True)
df = df.join(s)
df['Zonas'] = df['Zonas'].astype(str)
df.head()
# Out:
#   Tipo de Propiedad   Zona             Barrio Tipo de Barrio  \
# 0            Duplex    nan  Claros del Bosque            NaN
# 1            Duplex    Sur       Greenville 2  Con Seguridad
# 2              Casa    nan       La Herradura        Country
# 3              Casa  Norte     Villa Belgrano        Abierto
# 4              Casa    nan    Maipú Sección 2            NaN
#
#    Cantidad de Dormitorios  Cantidad de Baños  Cantidad de Cocheras  \
# 0                    3.000              3.000                 1.000
# 1                    3.000              2.000                 0.000
# 2                    3.000              3.000                 2.000
# 3                    3.000              4.000                 2.000
# 4                    4.000              4.000                 2.000
#
#   Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                    160                 180 185000.000
# 1                    NaN                 NaN 225000.000
# 2                    400                1592 380000.000
# 3               446 mts2          1.200 mts2 420000.000
# 4                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing  Cantidad de Dormitorios_was_missing  \
# 0                             False                                False
# 1                              True                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Cantidad de Baños_was_missing  Barrio_was_missing                Zonas
# 0                          False               False             Zona Sur
# 1                           True               False             Zona Sur
# 2                          False               False  Zona Cerro-Argüello
# 3                          False               False  Zona Cerro-Argüello
# 4                          False               False         Zona Sudeste

# %%
# Creating a new column containing references about the replaced NaN values in 'Zonas'
df.Zona = df.Zona.replace('nan',np.NaN)
df.Zonas = df.Zonas.replace('nan',np.NaN)
df['Zona_was_missing'] = df['Zonas'].isnull()

# %%
# Replacing the NaN values in 'Zonas' with values from the old category 'Zona'
df.Zonas.fillna(df.Zona, inplace=True)

# Deleting the old category 'Zona'
del df['Zona']

# Converting 'Centro' to 'Central'
df.Zonas = df.Zonas.replace('Centro', 'Central')
print('Lenght of Zona\'s NaN:', len(df.loc[df.Zonas.isnull()]))
# Out:
# Lenght of Zona's NaN: 0

# %%
# Droping the few rows containing NaN from 'Zonas'
df = df.loc[df.Zonas.notnull()]
print('Lenght of Zona\'s NaN:', len(df.loc[df.Zonas.isnull()]))
print('Lenght of dataframe:', len(df))

# Renaming 'Zonas' as 'Zona'
df.rename(columns={'Zonas': 'Zona'}, inplace=True)

# Removing the chars 'Zona ' from values
for i in df.Zona.unique():
  df.Zona.loc[df.Zona == i] = i.replace('Zona ','')

print(df.Zona.unique())
df.head()
# Out:
# Lenght of Zona's NaN: 0
# Lenght of dataframe: 9504
# ['Sur' 'Cerro-Argüello' 'Sudeste' 'Este' 'Noroeste' 'Sudoeste' 'Oeste'
#  'Norte' 'Central' 'Nordeste' 'Guiñazú']
#   Tipo de Propiedad             Barrio Tipo de Barrio  \
# 0            Duplex  Claros del Bosque            NaN
# 1            Duplex       Greenville 2  Con Seguridad
# 2              Casa       La Herradura        Country
# 3              Casa     Villa Belgrano        Abierto
# 4              Casa    Maipú Sección 2            NaN
#
#    Cantidad de Dormitorios  Cantidad de Baños  Cantidad de Cocheras  \
# 0                    3.000              3.000                 1.000
# 1                    3.000              2.000                 0.000
# 2                    3.000              3.000                 2.000
# 3                    3.000              4.000                 2.000
# 4                    4.000              4.000                 2.000
#
#   Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                    160                 180 185000.000
# 1                    NaN                 NaN 225000.000
# 2                    400                1592 380000.000
# 3               446 mts2          1.200 mts2 420000.000
# 4                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing  Cantidad de Dormitorios_was_missing  \
# 0                             False                                False
# 1                              True                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Cantidad de Baños_was_missing  Barrio_was_missing            Zona  \
# 0                          False               False             Sur
# 1                           True               False             Sur
# 2                          False               False  Cerro-Argüello
# 3                          False               False  Cerro-Argüello
# 4                          False               False         Sudeste
#
#    Zona_was_missing
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ### **Cleaning 'Tipo de Barrio'**

# %%
# Loading 'Tipo_de_Barrio.csv', which contains the 'Tipo de Barrio' for each 'Barrio'
tipo_barrio = pd.read_csv('/data/barrios/Tipo_de_Barrio.csv')
tipo_barrio.drop(columns=['Unnamed: 0'], inplace=True)
tipo_barrio.head()
# Out:
#               Con Seguridad           Cerrado               Country
# 0              Greenville 2     Ayres del Sur          Las Delicias
# 1               Manantiales  Palmas de Claret  Lomas de la Carolina
# 2      Altos de Manantiales     Santina Norte           Jockey Club
# 3  Miradores de Manantiales         Terranova             El Bosque
# 4    Riberas de Manantiales   Valle Escondido             La Cuesta

# %%
# Inserting a new column 'Tipo de Barrio 2' with Tipo_de_Barrio-values got from comparing 'Barrios' with the dataset 'Tipo_de_Barrio.csv'
tipo = []
for i in df.Barrio:
  boolean = True
  if i == 'Otro':
    tipo.append(np.NaN)
    boolean = False
  else:    
    for j in tipo_barrio.astype(str).values:
      for x in j:
        if i == x:
          tipo.append(tipo_barrio.columns[tipo_barrio.isin([x]).any()][0])
          boolean = False
  if boolean:
    tipo.append('Abierto')

s = pd.DataFrame(tipo, columns=['Tipo de Barrio 2'])
df = df.reset_index(drop=True)
df = df.join(s)
df.head()
# Out:
#   Tipo de Propiedad             Barrio Tipo de Barrio  \
# 0            Duplex  Claros del Bosque            NaN
# 1            Duplex       Greenville 2  Con Seguridad
# 2              Casa       La Herradura        Country
# 3              Casa     Villa Belgrano        Abierto
# 4              Casa    Maipú Sección 2            NaN
#
#    Cantidad de Dormitorios  Cantidad de Baños  Cantidad de Cocheras  \
# 0                    3.000              3.000                 1.000
# 1                    3.000              2.000                 0.000
# 2                    3.000              3.000                 2.000
# 3                    3.000              4.000                 2.000
# 4                    4.000              4.000                 2.000
#
#   Superficie Cubierta m2 Superficie Total m2      Valor  \
# 0                    160                 180 185000.000
# 1                    NaN                 NaN 225000.000
# 2                    400                1592 380000.000
# 3               446 mts2          1.200 mts2 420000.000
# 4                    316                 350 250000.000
#
#    Cantidad de Cocheras_was_missing  Cantidad de Dormitorios_was_missing  \
# 0                             False                                False
# 1                              True                                False
# 2                             False                                False
# 3                             False                                False
# 4                             False                                False
#
#    Cantidad de Baños_was_missing  Barrio_was_missing            Zona  \
# 0                          False               False             Sur
# 1                           True               False             Sur
# 2                          False               False  Cerro-Argüello
# 3                          False               False  Cerro-Argüello
# 4                          False               False         Sudeste
#
#    Zona_was_missing Tipo de Barrio 2
# 0             False          Cerrado
# 1             False    Con Seguridad
# 2             False          Country
# 3             False          Abierto
# 4             False          Abierto

# %%
# Creating a new column containing references about the replaced NaN values in 'Tipo de Barrio 2'
df['Tipo de Barrio_was_missing'] = df['Tipo de Barrio 2'].isnull()

# Replacing the NaN values in 'Tipo de Barrio 2' with values from the old category 'Tipo de Barrio'
df['Tipo de Barrio 2'].fillna(df['Tipo de Barrio'], inplace=True)
del df['Tipo de Barrio']
print('Lenght of Tipo de Barrio\'s NaN:', len(df.loc[df['Tipo de Barrio 2'].isnull()]))
# Out:
# Lenght of Tipo de Barrio's NaN: 30

# %%
# Cheking for kinds of values in'Tipo de Barrio'
print(df['Tipo de Barrio 2'].unique())

# Replacing 'Privado' with 'Cerrado'
df['Tipo de Barrio 2'] = df['Tipo de Barrio 2'].replace('Privado', 'Cerrado')
print(df['Tipo de Barrio 2'].unique())
# Out:
# ['Cerrado' 'Con Seguridad' 'Country' 'Abierto' nan]
# ['Cerrado' 'Con Seguridad' 'Country' 'Abierto' nan]

# %%
# Droping the rows containing NaN from 'Tipo de Barrio 2'
df = df.loc[df['Tipo de Barrio 2'].notnull()]
print('Lenght of Tipo de Barrio\'s NaN:', len(df.loc[df['Tipo de Barrio 2'].isnull()]))
print('Lenght of dataframe:', len(df))

# Renaming 'Tipo de Barrio 2' as 'Tipo de Barrio'
df.rename(columns={'Tipo de Barrio 2': 'Tipo de Barrio'}, inplace=True)
df.head()
# Out:
# Lenght of Tipo de Barrio's NaN: 0
# Lenght of dataframe: 9474
#   Tipo de Propiedad             Barrio  Cantidad de Dormitorios  \
# 0            Duplex  Claros del Bosque                    3.000
# 1            Duplex       Greenville 2                    3.000
# 2              Casa       La Herradura                    3.000
# 3              Casa     Villa Belgrano                    3.000
# 4              Casa    Maipú Sección 2                    4.000
#
#    Cantidad de Baños  Cantidad de Cocheras Superficie Cubierta m2  \
# 0              3.000                 1.000                    160
# 1              2.000                 0.000                    NaN
# 2              3.000                 2.000                    400
# 3              4.000                 2.000               446 mts2
# 4              4.000                 2.000                    316
#
#   Superficie Total m2      Valor  Cantidad de Cocheras_was_missing  \
# 0                 180 185000.000                             False
# 1                 NaN 225000.000                              True
# 2                1592 380000.000                             False
# 3          1.200 mts2 420000.000                             False
# 4                 350 250000.000                             False
#
#    Cantidad de Dormitorios_was_missing  Cantidad de Baños_was_missing  \
# 0                                False                          False
# 1                                False                           True
# 2                                False                          False
# 3                                False                          False
# 4                                False                          False
#
#    Barrio_was_missing            Zona  Zona_was_missing Tipo de Barrio  \
# 0               False             Sur             False        Cerrado
# 1               False             Sur             False  Con Seguridad
# 2               False  Cerro-Argüello             False        Country
# 3               False  Cerro-Argüello             False        Abierto
# 4               False         Sudeste             False        Abierto
#
#    Tipo de Barrio_was_missing
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %% [markdown]
# ## **Numerical features ('Superficie Cubierta m2' & 'Superficie Total m2')**

# %%
# Cleaning values from row data at 'Superficie Cubierta m2' and 'Superficie Total m2'
df['Superficie Cubierta m2'] = df['Superficie Cubierta m2'].astype(str).str.extract('(\d+)').astype(float)
df = df.loc[(df['Superficie Cubierta m2'] < 5000) & (df['Superficie Cubierta m2']  > 20) | (df['Superficie Cubierta m2'].isnull())]
df['Superficie Total m2'] = df['Superficie Total m2'].astype(str).str.extract('(\d+)').astype(float)
df = df.loc[(df['Superficie Total m2'] < 10000) & (df['Superficie Total m2']  > 20) | (df['Superficie Total m2'].isnull())]

# %%
# Analysing outliers from 'Superficie Cubierta m2' & 'Superficie Total m2'
plt.subplot(1, 2, 1)
sns.boxplot(df['Superficie Cubierta m2'])
plt.title('Superficie Cubierta m2')
plt.subplot(1, 2, 2)
sns.boxplot(df['Superficie Total m2'])
plt.title('Superficie Total m2')
print('Lenght:',len(df)) #Lenght: 7225
plt.show()
# Out:
# Lenght: 9356

# %%
# Cleaning big outliers from 'Superficie Cubierta m2' & 'Superficie Total m2'
df = df.loc[(df['Superficie Cubierta m2'] < 2000) | (df['Superficie Cubierta m2'].isnull()) ]
df = df.loc[(df['Superficie Total m2'] < 6000) | (df['Superficie Total m2'].isnull()) ]

# Plotting results
plt.subplot(1, 2, 1)
sns.boxplot(df['Superficie Cubierta m2'])
plt.title('Superficie Cubierta m2')
plt.subplot(1, 2, 2)
sns.boxplot(df['Superficie Total m2'])
plt.title('Superficie Total m2')
print('Lenght:',len(df))
plt.show()
# Out:
# Lenght: 9349

# %%
# Creating new columns with data about the replacement of NaN in 'Superficie Cubierta m2' & 'Superficie Total m2'
for i in ['Superficie Cubierta m2', 'Superficie Total m2']:
  df[i + '_was_missing'] = df[i].isnull()
df.head()
# Out:
#   Tipo de Propiedad             Barrio  Cantidad de Dormitorios  \
# 0            Duplex  Claros del Bosque                    3.000
# 1            Duplex       Greenville 2                    3.000
# 2              Casa       La Herradura                    3.000
# 4              Casa    Maipú Sección 2                    4.000
# 6              Casa    Maipú Sección 2                    3.000
#
#    Cantidad de Baños  Cantidad de Cocheras  Superficie Cubierta m2  \
# 0              3.000                 1.000                 160.000
# 1              2.000                 0.000                     nan
# 2              3.000                 2.000                 400.000
# 4              4.000                 2.000                 316.000
# 6              2.000                 1.000                 221.000
#
#    Superficie Total m2      Valor  Cantidad de Cocheras_was_missing  \
# 0              180.000 185000.000                             False
# 1                  nan 225000.000                              True
# 2             1592.000 380000.000                             False
# 4              350.000 250000.000                             False
# 6              296.000 135000.000                             False
#
#    Cantidad de Dormitorios_was_missing  Cantidad de Baños_was_missing  \
# 0                                False                          False
# 1                                False                           True
# 2                                False                          False
# 4                                False                          False
# 6                                False                          False
#
#    Barrio_was_missing            Zona  Zona_was_missing Tipo de Barrio  \
# 0               False             Sur             False        Cerrado
# 1               False             Sur             False  Con Seguridad
# 2               False  Cerro-Argüello             False        Country
# 4               False         Sudeste             False        Abierto
# 6               False         Sudeste             False        Abierto
#
#    Tipo de Barrio_was_missing  Superficie Cubierta m2_was_missing  \
# 0                       False                               False
# 1                       False                                True
# 2                       False                               False
# 4                       False                               False
# 6                       False                               False
#
#    Superficie Total m2_was_missing
# 0                            False
# 1                             True
# 2                            False
# 4                            False
# 6                            False

# %%
# Plotting distributions of 'Superficie Cubierta m2' & 'Superficie Total m2'
sup = df.dropna(subset=['Superficie Cubierta m2','Superficie Total m2'])

sup = sup.loc[(sup['Superficie Cubierta m2'] < 350) ]
sup = sup.loc[(sup['Superficie Total m2'] < 730) ]

# Plotting results
plt.subplot(2, 2, 1)
sns.boxplot(sup['Superficie Cubierta m2'])
plt.title('Superficie Cubierta m2')
plt.subplot(2, 2, 2)
sns.boxplot(sup['Superficie Total m2'])
plt.title('Superficie Total m2')
print('Lenght:',len(sup))

plt.subplot(2, 2, 3)
sns.distplot(sup['Superficie Cubierta m2'], fit=norm)
plt.title('Superficie Cubierta m2')
plt.subplot(2, 2, 4)
sns.distplot(sup['Superficie Total m2'], fit=norm)
plt.title('Superficie Total m2')

plt.show()
# Out:
# Lenght: 5169

# %%
# Analysing correlations between Valor', Superficie Cubierta m2' & 'Superficie Total m2'
plt.subplot(1, 2, 1)
plt.scatter(sup['Superficie Cubierta m2'], sup.Valor)
plt.title('Superficie Cubierta m2')
plt.subplot(1, 2, 2)
plt.scatter(sup['Superficie Total m2'], sup.Valor)
plt.title('Superficie Total m2')
plt.show() # There are positive correlations between 'Superficie Cubierta m2'&'Superficie Total m2' and 'Valor'

# %%
#Apply np.log1p which applies log(1+x) to all elements of 'Superficie Cubierta m2' & 'Superficie Total m2', normalizing their distributions
sup['Superficie Cubierta m2'] = np.log1p(sup['Superficie Cubierta m2'])
sup['Superficie Total m2'] = np.log1p(sup['Superficie Total m2'])

#Checking the new distributions
plt.subplot(1, 2, 1)
sns.distplot(sup['Superficie Cubierta m2'], fit=norm)
plt.title('Superficie Cubierta m2')
plt.subplot(1, 2, 2)
sns.distplot(sup['Superficie Total m2'], fit=norm)
plt.title('Superficie Total m2')

plt.show()

# %%
#Apply np.log1p which applies log(1+x) to all elements of the column 'Valor', normalizing its distribution
sup.Valor = np.log1p(sup.Valor)

#Checking the new distribution 
mu, sigma = norm.fit(sup.Valor)
print('Mean: %s | Standard Deviation: %s'%("%.0f"% mu,"%.0f"% sigma)) 

sns.distplot(sup.Valor, fit=norm) 
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')

plt.show()
# Out:
# Mean: 12 | Standard Deviation: 1

# %%
# Analysing correlations between Valor', Superficie Cubierta m2' & 'Superficie Total m2'
plt.subplot(1, 2, 1)
plt.scatter(sup['Superficie Cubierta m2'], sup.Valor)
plt.title('Superficie Cubierta m2')
plt.subplot(1, 2, 2)
plt.scatter(sup['Superficie Total m2'], sup.Valor)
plt.title('Superficie Total m2')
plt.show() # There are positive correlations between 'Superficie Cubierta m2'&'Superficie Total m2' and 'Valor'

# %%
col = ['Valor',
       'Cantidad de Dormitorios',
       'Cantidad de Baños',
       'Superficie Cubierta m2',
       'Superficie Total m2',
      ]
sup = sup[col]
sup.head()
# Out:
#     Valor  Cantidad de Dormitorios  Cantidad de Baños  Superficie Cubierta m2  \
# 0  12.128                    3.000              3.000                   5.081
# 4  12.429                    4.000              4.000                   5.759
# 6  11.813                    3.000              2.000                   5.403
# 9  11.736                    3.000              1.000                   5.226
# 10 11.951                    3.000              2.000                   5.081
#
#     Superficie Total m2
# 0                 5.198
# 4                 5.861
# 6                 5.694
# 9                 6.078
# 10                5.707

# %%
X = sup.drop(columns=['Superficie Cubierta m2', 'Superficie Total m2'])
y = sup['Superficie Cubierta m2']

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

def log_XGB (X,y):
    # Split into validation and training data
    train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

    # Make validation predictions and calculate mean absolute error
    def get_mae(m, train_X, val_X, train_y, val_y):
        my_model = XGBRegressor(n_estimators=50000, learning_rate=0.01)
        my_model.fit(train_X, train_y, early_stopping_rounds=m, eval_set=[(val_X, val_y)], verbose=False)
        predictions = my_model.predict(val_X)
        mae = mean_absolute_error(np.expm1(predictions), np.expm1(val_y))
        return mae

    mae_values = {}

    for max_leaf_nodes in range(0,300, 10):
      mae_values[max_leaf_nodes] = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    min_mae_value = min(mae_values, key=mae_values.get)
    print("   * XGBRegressor with early_stopping_rounds: {:,.2f}".format(mae_values[min_mae_value]), 
          '(with',min_mae_value, 'stops)')
    return min_mae_value

# %%
m = log_XGB (X,y)
# Out:
#    * XGBRegressor with early_stopping_rounds: 32.70 (with 290 stops)

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = XGBRegressor(n_estimators=50000, learning_rate=0.01)
my_model.fit(train_X, train_y, early_stopping_rounds=m, eval_set=[(val_X, val_y)], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=50000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
X = df.loc[df['Superficie Cubierta m2'].isnull()]
X = X[['Valor','Cantidad de Dormitorios','Cantidad de Baños']]
X.Valor = np.log1p(X.Valor)
predictions = my_model.predict(X)
print(len(predictions))
print(len(df['Superficie Cubierta m2'][df['Superficie Cubierta m2'].isnull()]))
# Out:
# 2063
# 2063

# %%
df['Superficie Cubierta m2'][df['Superficie Cubierta m2'].isnull()] = np.expm1(predictions)
plt.scatter(df['Superficie Cubierta m2'], df.Valor)

# %%
X = sup.drop(columns=['Superficie Cubierta m2', 'Superficie Total m2'])
y = sup['Superficie Total m2']

m = log_XGB (X,y)
# Out:
#    * XGBRegressor with early_stopping_rounds: 95.02 (with 170 stops)

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
my_model = XGBRegressor(n_estimators=50000, learning_rate=0.01)
my_model.fit(train_X, train_y, early_stopping_rounds=m, eval_set=[(val_X, val_y)], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.01, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=50000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
X = df.loc[df['Superficie Total m2'].isnull()]
X = X[['Valor','Cantidad de Dormitorios','Cantidad de Baños']]
X.Valor = np.log1p(X.Valor)
predictions = my_model.predict(X)
print(len(predictions))
print(len(df['Superficie Total m2'][df['Superficie Total m2'].isnull()]))
# Out:
# 1922
# 1922

# %%
df['Superficie Total m2'][df['Superficie Total m2'].isnull()] = np.expm1(predictions)
plt.scatter(df['Superficie Total m2'], df.Valor)

# %%
print('Lenght:', len(df))
# Out:
# Lenght: 9349

# %% [markdown]
# ## **Final integration of the DataFrame**

# %%
# Checking for NaN in the entire DataFrame
for i in df.columns:
  df[i] = df[i].replace('nan',np.NaN)
df.isnull().sum()
# Out:
# Tipo de Propiedad                      0
# Barrio                                 0
# Cantidad de Dormitorios                0
# Cantidad de Baños                      0
# Cantidad de Cocheras                   0
# Superficie Cubierta m2                 0
# Superficie Total m2                    0
# Valor                                  0
# Cantidad de Cocheras_was_missing       0
# Cantidad de Dormitorios_was_missing    0
# Cantidad de Baños_was_missing          0
# Barrio_was_missing                     0
# Zona                                   0
# Zona_was_missing                       0
# Tipo de Barrio                         0
# Tipo de Barrio_was_missing             0
# Superficie Cubierta m2_was_missing     0
# Superficie Total m2_was_missing        0
# dtype: int64

# %%
# Re-ordening all the columns in the dataframe
col = ['Tipo de Propiedad',
       'Zona',
       'Barrio',
       'Tipo de Barrio',
       'Cantidad de Dormitorios',
       'Cantidad de Baños',
       'Cantidad de Cocheras',
       'Superficie Cubierta m2',
       'Superficie Total m2',
       'Zona_was_missing',
       'Barrio_was_missing',
       'Tipo de Barrio_was_missing',
       'Cantidad de Dormitorios_was_missing',
       'Cantidad de Baños_was_missing',
       'Cantidad de Cocheras_was_missing',
       'Superficie Cubierta m2_was_missing',
       'Superficie Total m2_was_missing',
       'Valor',
      ] 
df = df[col]
print('Lenght:', len(df))  
df.head()
# Out:
# Lenght: 9349
#   Tipo de Propiedad            Zona             Barrio Tipo de Barrio  \
# 0            Duplex             Sur  Claros del Bosque        Cerrado
# 1            Duplex             Sur       Greenville 2  Con Seguridad
# 2              Casa  Cerro-Argüello       La Herradura        Country
# 4              Casa         Sudeste    Maipú Sección 2        Abierto
# 6              Casa         Sudeste    Maipú Sección 2        Abierto
#
#    Cantidad de Dormitorios  Cantidad de Baños  Cantidad de Cocheras  \
# 0                    3.000              3.000                 1.000
# 1                    3.000              2.000                 0.000
# 2                    3.000              3.000                 2.000
# 4                    4.000              4.000                 2.000
# 6                    3.000              2.000                 1.000
#
#    Superficie Cubierta m2  Superficie Total m2  Zona_was_missing  \
# 0                 160.000              180.000             False
# 1                 182.136              296.814             False
# 2                 400.000             1592.000             False
# 4                 316.000              350.000             False
# 6                 221.000              296.000             False
#
#    Barrio_was_missing  Tipo de Barrio_was_missing  \
# 0               False                       False
# 1               False                       False
# 2               False                       False
# 4               False                       False
# 6               False                       False
#
#    Cantidad de Dormitorios_was_missing  Cantidad de Baños_was_missing  \
# 0                                False                          False
# 1                                False                           True
# 2                                False                          False
# 4                                False                          False
# 6                                False                          False
#
#    Cantidad de Cocheras_was_missing  Superficie Cubierta m2_was_missing  \
# 0                             False                               False
# 1                              True                                True
# 2                             False                               False
# 4                             False                               False
# 6                             False                               False
#
#    Superficie Total m2_was_missing      Valor
# 0                            False 185000.000
# 1                             True 225000.000
# 2                            False 380000.000
# 4                            False 250000.000
# 6                            False 135000.000

# %%
a = {}
for i in df.Barrio.unique():
  a[i] = len(df.loc[df.Barrio == i]) 
a
# Out:
# {'1 de Mayo': 8,
#  '20 de Junio': 6,
#  'ATE': 10,
#  'Acosta': 5,
#  'Aeronáutico': 3,
#  'Alameda': 2,
#  'Alberdi': 94,
#  'Alberto': 1,
#  'Alejandro Centeno': 55,
#  'Alta Córdoba': 182,
#  'Altamira': 13,
#  'Alto Alberdi': 144,
#  'Alto Palermo': 36,
#  'Alto Verde': 71,
#  'Altos de La Calera': 3,
#  'Altos de Manantiales': 35,
#  'Altos de San Martín': 7,
#  'Altos de Villa Cabrera': 15,
#  'Altos de Vélez Sársfield': 10,
#  'Altos del Chateau': 25,
#  'Ameghino Norte': 2,
#  'Ameghino Sud': 11,
#  'Amp. Res. America': 16,
#  'Ampliación Jardín Espinosa': 1,
#  'Ampliación Pueyrredón': 2,
#  'Ampliación Residencial América': 1,
#  'Argüello': 359,
#  'Argüello Norte': 26,
#  'Avenida': 5,
#  'Ayacucho': 51,
#  'Ayres del Sur': 6,
#  'Bajo Galán': 2,
#  'Bajo General Paz': 1,
#  'Barrancas Norte': 3,
#  'Bella Vista': 14,
#  'Bialet Massé': 12,
#  'Brigadier San Martín': 1,
#  'Cabo Farina': 1,
#  'Caseros': 1,
#  'Casonas Del Sur': 3,
#  'Cañuelas': 30,
#  'Centenario': 49,
#  'Centro': 141,
#  'Centro América': 25,
#  'Cerro Chico': 24,
#  'Cerro Norte': 6,
#  'Cerro de las Rosas': 327,
#  'Cerveceros': 2,
#  'Chacra Escondida': 2,
#  'Chacra del Norte': 155,
#  'Chacra del Sur': 28,
#  'Chacras de la Villa': 46,
#  'Chateau Carreras': 21,
#  'Cinco Lomas': 19,
#  'Ciudadela': 4,
#  'Claros del Bosque': 141,
#  'Cofico': 75,
#  'Colinas de Vélez Sársfield': 51,
#  'Colinas del Cerro': 15,
#  'Colonia Lola': 1,
#  'Colón': 117,
#  'Comarca de Allende': 31,
#  'Condor Alto': 33,
#  'Crisol Norte': 19,
#  'Crisol Sud': 30,
#  'Cuatro Hojas': 49,
#  'Cuesta Colorada': 16,
#  'Cumbres de Villa Allende': 6,
#  'Cumbres del Golf': 18,
#  'Córdoba 5': 27,
#  'Docta': 13,
#  'Ducasse': 7,
#  'Déan Funes': 8,
#  'Ejército Argentino': 10,
#  'El Bosque': 54,
#  'El Cabildo': 4,
#  'El Refugio': 10,
#  'El Rodeo': 7,
#  'El Talar de Mendiolaza': 50,
#  'El Trebol': 21,
#  'Empalme': 34,
#  'Escobar': 41,
#  'Estación Flores': 1,
#  'Estancia La Lucila': 1,
#  'Estancia Q2': 55,
#  'Ferreyra': 3,
#  'Ferroviario Mitre': 2,
#  'Fincas Del Sur II': 19,
#  'Fincas del Sur I': 27,
#  'Fortín del Pozo': 5,
#  'General Artigas': 1,
#  'General Belgrano': 2,
#  'General Bustos': 51,
#  'General Paz': 117,
#  'General Pueyrredón': 72,
#  'Golf': 73,
#  'Granadero Pringles': 1,
#  'Granja de Funes': 72,
#  'Greenville 2': 15,
#  'Guayaquil': 3,
#  'Guiñazú': 4,
#  'Güemes': 40,
#  'Hipólito Yrigoyen': 2,
#  'Hogar Propio': 1,
#  'Inaudi': 44,
#  'Independencia': 1,
#  'Industrial Este': 3,
#  'Iponá': 13,
#  'Irupé': 1,
#  'Ituzaingó': 14,
#  'Jardines del Jockey': 11,
#  'Jardín': 136,
#  'Jardín Claret': 24,
#  'Jardín Espinosa': 84,
#  'Jardín Hipódromo': 1,
#  'Jardín de los Boulevares': 7,
#  'Jardín del Pilar': 9,
#  'Jardín del Sud': 2,
#  'Jerónimo Luis de Cabrera': 1,
#  'Jockey Club': 52,
#  'José Hernández': 1,
#  'José Ignacio Díaz': 13,
#  'Juan B. Justo': 2,
#  'Juan XXIII': 9,
#  'Juniors': 50,
#  'Kennedy': 1,
#  'La Calandria': 7,
#  'La Calera': 51,
#  'La Carolina': 17,
#  'La Cascada': 3,
#  'La Catalina': 43,
#  'La Cuesta': 75,
#  'La Estanzuela': 28,
#  'La France': 13,
#  'La Herradura': 39,
#  'La Morada': 18,
#  'La Paloma': 19,
#  'La Paya I': 2,
#  'La Paya II': 9,
#  'La Reserva': 7,
#  'La Rufina': 64,
#  'La Salle': 11,
#  'La Santina': 8,
#  'Lamadrid': 5,
#  'Las Cañitas': 57,
#  'Las Corzuelas': 5,
#  'Las Dalias': 6,
#  'Las Delicias': 44,
#  'Las Flores': 17,
#  'Las Lilas': 1,
#  'Las Magnolias': 8,
#  'Las Margaritas': 31,
#  'Las Palmas': 41,
#  'Las Rosas': 16,
#  'Las Violetas': 2,
#  'Liceo General Paz': 12,
#  'Lomas Este': 44,
#  'Lomas de San Martín': 39,
#  'Lomas de la Carolina': 107,
#  'Lomas del Chateau': 25,
#  'Lomas del Suquía': 2,
#  'Los Boulevares': 71,
#  'Los Ceibos': 3,
#  'Los Gigantes': 15,
#  'Los Granados': 7,
#  'Los Mimbres': 11,
#  'Los Naranjos': 30,
#  'Los Olmos': 7,
#  'Los Olmos Sud': 1,
#  'Los Paraísos': 10,
#  'Los Pinos': 1,
#  'Los Plátanos': 17,
#  'Los Prados': 9,
#  'Los Robles': 8,
#  'Los Sauces': 8,
#  'Los Álamos': 4,
#  'Maipú': 29,
#  'Maipú Sección 1': 39,
#  'Maipú Sección 2': 29,
#  'Malagueño': 30,
#  'Manantiales': 64,
#  'Marcos Sastre': 1,
#  'Marechal': 1,
#  'Mariano Balcarce': 3,
#  'Mariano Fragueiro': 7,
#  'Marqués de Sobremonte': 74,
#  'Matienzo': 45,
#  'Mauller': 1,
#  'Maurizi': 1,
#  'Mendiolaza': 81,
#  'Mendiolaza Golf': 13,
#  'Mercantil': 5,
#  'Mirador': 3,
#  'Miradores de Manantiales': 93,
#  'Miralta': 1,
#  'Nueva Córdoba': 39,
#  'Nueva Italia': 3,
#  'Nuevo Urca': 19,
#  'Observatorio': 35,
#  'Otro': 253,
#  'Oña': 2,
#  'Padre Claret': 21,
#  'Palermo Bajo': 20,
#  'Palmar': 1,
#  'Palmas de Claret': 18,
#  'Panamericano': 8,
#  'Parque Alameda': 4,
#  'Parque Atlántica': 10,
#  'Parque Capital': 27,
#  'Parque Capital Sud': 1,
#  'Parque Chacabuco': 34,
#  'Parque Don Bosco': 39,
#  'Parque Futura': 1,
#  'Parque Gorema': 10,
#  'Parque Horizonte': 46,
#  'Parque Jorge Newbery': 14,
#  'Parque Latino': 4,
#  'Parque Liceo Sección 3': 2,
#  'Parque Los Molinos': 7,
#  'Parque Montecristo': 5,
#  'Parque Republica': 6,
#  'Parque San Carlos': 14,
#  'Parque Sarmiento': 3,
#  'Parque Vélez Sársfield': 88,
#  'Paso de los Andes': 33,
#  'Patria': 4,
#  'Patricios': 14,
#  'Poeta Lugones': 108,
#  'Pque. Liceo I': 13,
#  'Primera Junta': 1,
#  'Providencia': 33,
#  'Puente Blanco': 2,
#  'Quebrada de las Rosas': 67,
#  'Quinta Santa Ana': 11,
#  'Quintas de Argüello': 48,
#  'Quisquisacate': 1,
#  'Ramón J. Cárcano': 2,
#  'Remedios de Escalada': 1,
#  'Renacimiento': 1,
#  'Res. Sud': 2,
#  'Res. Vélez Sársfield': 33,
#  'Residencial América': 7,
#  'Residencial Chateau': 1,
#  'Residencial Olivos': 1,
#  'Residencial San Carlos': 1,
#  'Residencial San Roque': 1,
#  'Residencial Santa Ana': 3,
#  'Residencial Sud': 2,
#  'Residencial Vélez Sársfield': 11,
#  'Riberas de Manantiales': 11,
#  'Rivadavia': 2,
#  'Rivera Indarte': 16,
#  'Rogelio Martinez': 17,
#  'Rosedal': 17,
#  'SMATA': 12,
#  'San Alfonso del Talar': 46,
#  'San Antonio': 5,
#  'San Cayetano': 4,
#  'San Daniel': 3,
#  'San Felipe': 1,
#  'San Fernando': 32,
#  'San Francisco': 10,
#  'San Ignacio': 1,
#  'San Isidro': 129,
#  'San Javier': 1,
#  'San José': 11,
#  'San Lorenzo': 8,
#  'San Martín': 41,
#  'San Martín Norte': 1,
#  'San Nicolás': 5,
#  'San Pablo': 16,
#  'San Rafael': 5,
#  'San Salvador': 74,
#  'San Vicente': 79,
#  'Santa Cecilia': 4,
#  'Santa Clara de Asís': 6,
#  'Santa Isabel': 14,
#  'Santa Rita': 5,
#  'Santa Rosa': 2,
#  'Santina Norte': 35,
#  'Sargento Cabral': 1,
#  'Sarmiento': 14,
#  'Siete Soles': 13,
#  'Solares de San Alfonso': 12,
#  'Solares de Santa María': 9,
#  'Suárez': 4,
#  'Tablada Park': 41,
#  'Talleres Este': 15,
#  'Talleres Oeste': 6,
#  'Talleres Sud': 5,
#  'Tejas III': 13,
#  'Tejas del Sur I': 28,
#  'Tejas del Sur II': 11,
#  'Teniente Benjamín Matienzo': 4,
#  'Terranova': 5,
#  'Terrazas de La Estanzuela': 10,
#  'Terrazas de Villa Allende': 24,
#  'UOCRA': 3,
#  'Urca': 213,
#  'Urquiza': 4,
#  'Valle Cercano': 28,
#  'Valle Escondido': 167,
#  'Valle del Golf': 1,
#  'Valle del Sol': 23,
#  'Vicor': 5,
#  'Villa Adela': 7,
#  'Villa Alberdi': 1,
#  'Villa Allende': 325,
#  'Villa Allende Parque': 33,
#  'Villa Argentina': 8,
#  'Villa Azalais': 4,
#  'Villa Belgrano': 374,
#  'Villa Bustos': 1,
#  'Villa Cabrera': 126,
#  'Villa Corina': 5,
#  'Villa Cornu': 3,
#  'Villa Coronel Olmedo': 3,
#  'Villa El Libertador': 5,
#  'Villa Esquiú': 2,
#  'Villa General Urquiza': 2,
#  'Villa Gran Parque': 2,
#  'Villa Los Angeles': 1,
#  'Villa Marta': 8,
#  'Villa Páez': 2,
#  'Villa Revol': 2,
#  'Villa Rivera Indarte': 193,
#  'Villa San Carlos': 35,
#  'Villa Warcalde': 91,
#  'Yapeyú': 18,
#  'Yofre I': 4,
#  'Yofre Norte': 4,
#  'Yofre Sud': 6,
#  'Zumaran': 23}

# %% [markdown]
# ## **Exporting cleaned DataFrame**

# %%
df.to_csv('Cleaned_Venta_casas.csv', encoding='utf_8_sig')
